# %%
# Dependencies
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from sqlalchemy import create_engine

# Import key
from spotify_keys import CLIENT_ID,CLIENT_SECRET

# %%
# Applying spotipy library to get the data
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET))

# %%
# Using .search() function to query first 50 songs in 2022
fifty_songs_2022 = sp.search(q='year:2022', limit=50, offset=0)
result_fifty_2022 = fifty_songs_2022['tracks']['items']

# %%
# Looping through 2022 data result
track_name =[]
album_type=[]
album_id=[]
artist_name=[]
release_date=[]
popularity=[]
disc_number=[]
external_url=[]


for item in result_fifty_2022:
    track_name.append(item['name'])
    album_type.append(item['album']['album_type'])
    album_id.append(item['album']['id'])
    artist_name.append(', '.join(artist['name'] for artist in item['artists']))
    release_date.append(item['album']['release_date'])
    popularity.append(item['popularity'])
    disc_number.append(item['disc_number'])
    external_url.append(item['external_urls']['spotify'])

# %%
# Create 2022 data frame
result_fifty_2022_df = pd.DataFrame({
    "Track Name":track_name,
    "Album Type":album_type,
    "Album ID":album_id,
    "Artist Name":artist_name,
    "Release Date":release_date,
    "Popularity":popularity,
    "Disc Number":disc_number,
    "External URL":external_url,
})

#Print out the first five lines
result_fifty_2022_df.head()
# Out:
#                       Track Name Album Type                Album ID  \
# 0        Something in the Orange     single  1CmTOKCeyz1aHH04OwvTPv
# 1                      Kill Bill      album  1nrVofqDRs7cpWXJ49qTnP
# 2                      Anti-Hero      album  151w1FgRZfnKZA9FEcg9Z3
# 3                         Snooze      album  07w0rG5TETcyihsEIZR3qG
# 4  Jimmy Cooks (feat. 21 Savage)      album  3cf4iSSKd8ffTncbtKljXw
#
#         Artist Name Release Date  Popularity  Disc Number  \
# 0        Zach Bryan   2022-04-22          89            1
# 1               SZA   2022-12-08          93            1
# 2      Taylor Swift   2022-10-21          94            1
# 3               SZA   2022-12-09          91            1
# 4  Drake, 21 Savage   2022-06-17          90            1
#
#                                         External URL
# 0  https://open.spotify.com/track/3WMj8moIAXJhHsy...
# 1  https://open.spotify.com/track/1Qrg8KqiBpW07V7...
# 2  https://open.spotify.com/track/0V3wPSX9ygBnCm8...
# 3  https://open.spotify.com/track/4iZ4pt7kvcaH6Yo...
# 4  https://open.spotify.com/track/3F5CgOj3wFlRv51...

# %%
# Using .search() function to query first 50 songs in 2021
fifty_songs_2021 = sp.search(q='year:2021', limit=50, offset=0)
result_fifty_2021 = fifty_songs_2021['tracks']['items']

# %%
# Looping through 2021 data result
track_name =[]
album_type=[]
album_id=[]
artist_name=[]
release_date=[]
popularity=[]
disc_number=[]
external_url=[]


for item in result_fifty_2021:
    track_name.append(item['name'])
    album_type.append(item['album']['album_type'])
    album_id.append(item['album']['id'])
    artist_name.append(', '.join(artist['name'] for artist in item['artists']))
    release_date.append(item['album']['release_date'])
    popularity.append(item['popularity'])
    disc_number.append(item['disc_number'])
    external_url.append(item['external_urls']['spotify'])

# %%
# Create 2021 data frame
result_fifty_2021_df = pd.DataFrame({
    "Track Name":track_name,
    "Album Type":album_type,
    "Album ID":album_id,
    "Artist Name":artist_name,
    "Release Date":release_date,
    "Popularity":popularity,
    "Disc Number":disc_number,
    "External URL":external_url,
})

#Print out the first five lines
result_fifty_2021_df.head()
# Out:
#               Track Name Album Type                Album ID  \
# 0          Wasted On You      album  6JlCkqkqobGirPsaleJpFr
# 1         Por las Noches     single  6USJaTtVIy0YH5hhzOWVHe
# 2       The Color Violet      album  5Gm2XKBgnlzd6qTi7LE1z2
# 3               Buy Dirt      album  2y9DFhTWC7QQJMvygK0TzO
# 4  More Than My Hometown      album  6JlCkqkqobGirPsaleJpFr
#
#                 Artist Name Release Date  Popularity  Disc Number  \
# 0             Morgan Wallen   2021-01-08          87            1
# 1                Peso Pluma   2021-06-11          90            1
# 2                Tory Lanez   2021-12-10          88            1
# 3  Jordan Davis, Luke Bryan   2021-05-21          84            1
# 4             Morgan Wallen   2021-01-08          81            1
#
#                                         External URL
# 0  https://open.spotify.com/track/3cBsEDNhFI9E82v...
# 1  https://open.spotify.com/track/2VzCjpKvPB1l1tq...
# 2  https://open.spotify.com/track/3azJifCSqg9fRij...
# 3  https://open.spotify.com/track/69AIpwGNLxr4qS1...
# 4  https://open.spotify.com/track/5OELUCYgOHKFAvC...

# %%
# Create data base connection
database_path = "spotify_fiftysongs_2022_2021.db"
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
# Set up the table names for 2022 and 2021 result
fifty_2022 = "spotify_fifty_songs_2022"
fifty_2021 = "spotify_fifty_songs_2021"

# Store the 2022 and 2021 result data into database
result_fifty_2022_df.to_sql(fifty_2022, con=engine, if_exists='replace', index=False)
result_fifty_2021_df.to_sql(fifty_2021, con=engine, if_exists='replace', index=False)
# Out:
# 50

# %%
# Close the connection
conn.close()
